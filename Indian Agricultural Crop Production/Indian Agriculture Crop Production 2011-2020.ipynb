# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
agri=pd.read_csv("E:\MBA Semester II\Python\Data sets\India Agriculture Crop Production 2010-2020.csv")

# %%
agri
# Out:
#                               State                  District      Crop  \
# 0       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 1       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 2       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 3       Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut
# 4       Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut
# ...                             ...                       ...       ...
# 319817                  West Bengal               MURSHIDABAD     Wheat
# 319818                  West Bengal                     NADIA     Wheat
# 319819                  West Bengal         PASCHIM BARDHAMAN     Wheat
# 319820                  West Bengal           PURBA BARDHAMAN     Wheat
# 319821                  West Bengal                   PURULIA     Wheat
#
#            Year Season     Area Area_Units  Production Production_Units  \
# ...

# %%
agri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319822 entries, 0 to 319821
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   State             319822 non-null  object
#  1   District          319822 non-null  object
#  2   Crop              319822 non-null  object
#  3   Year              319822 non-null  object
#  4   Season            319822 non-null  object
#  5   Area              319822 non-null  float64
#  6   Area_Units        319822 non-null  object
#  7   Production        315806 non-null  float64
#  8   Production_Units  319822 non-null  object
#  9   Yield             315806 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 24.4+ MB

# %%
agri.describe()
# Out:
#                Area    Production          Yield
# count  3.198220e+05  3.158060e+05  315806.000000
# mean   1.097665e+04  4.572946e+04       4.876108
# std    3.785806e+04  4.022240e+05      17.968075
# min    4.000000e-03  0.000000e+00       0.000000
# 25%    6.100000e+01  7.300000e+01       0.611100
# 50%    4.330000e+02  6.350000e+02       1.100000
# 75%    3.408750e+03  6.355000e+03       2.714300
# max    1.133397e+06  2.069354e+07    4070.000000

# %%
plt.figure(figsize=(15,20))
SP=agri.groupby('State')['Production'].agg('mean')
SP.sort_values(ascending=True,inplace=True)
SP.plot(kind='barh', color='red')
# Out:
# <AxesSubplot:ylabel='State'>

# %% [markdown]
# ### The above bar plot shows the overall Production in state wise between the year of 2010 to 2020. Punjab is the more production state combare to the all other states.

# %%
plt.figure(figsize=(15,10))
CP=agri.groupby('Crop')['Production'].agg('mean')
CP.sort_values(ascending=True,inplace=True)
CP.plot(kind='barh',color='green')
# Out:
# <AxesSubplot:ylabel='Crop'>

# %% [markdown]
# ### The above bar plot shows the overall Production in Crops.Sugarcane is the more producable crop in all states.

# %%
plt.figure(figsize=(15,10))
Sea=agri.groupby('Season')['Production'].agg('mean')
Sea.sort_values(ascending=False,inplace=True)
Sea.plot(kind='bar',color='purple')
# Out:
# <AxesSubplot:xlabel='Season'>

# %% [markdown]
# ### The above bar plot shows the overall Production in season. Whole year crops only produced more crops.

# %%
plt.figure(figsize=(15,10))
YP=agri.groupby('Year')['Production'].agg('mean')
YP.sort_values(ascending=False,inplace=True)
YP.plot(kind='bar',color='violet')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### The above bar plot shows the overall Production in year wise. In 2014-15 period only the more crops are produced combare to the all years.

# %% [markdown]
# ### The above bar plot shows the how much farming areas are in states. The most number of farming areas are there in Punjab state only.

# %%
plt.figure(figsize=(15,10))
CY=agri.groupby('Crop')['Yield'].agg('mean')
CY.sort_values(ascending=True,inplace=True)
CY.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Crop'>

# %% [markdown]
# ### The above bar plot shows the how much Yield was get it in the crops. Sugarcane is the more yeild crop when combare to the other crops.
# ### The yield was calculated in how much the production / the total area.

# %%
States=agri.groupby('State')
ANI=States.get_group('Andaman and Nicobar Islands')
ANI
# Out:
#                               State                  District      Crop  \
# 0       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 1       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 2       Andaman and Nicobar Islands                  NICOBARS  Arecanut
# 3       Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut
# 4       Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut
# ...                             ...                       ...       ...
# 307525  Andaman and Nicobar Islands                  NICOBARS  Turmeric
# 307526  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Turmeric
# 307527  Andaman and Nicobar Islands            SOUTH ANDAMANS  Turmeric
# 307528  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN      Urad
# 307529  Andaman and Nicobar Islands            SOUTH ANDAMANS      Urad
#
#            Year Season     Area Area_Units  Production Production_Units  \
# ...

# %%
sns.pairplot(ANI,hue='Season')

# %% [markdown]
# ### Whole year season is the most crop production in  Andaman and Nicobar Islands.

# %%
States=agri.groupby('State')
AP=States.get_group('Andhra Pradesh')
AP
# Out:
#                  State       District      Crop     Year      Season    Area  \
# 158     Andhra Pradesh      ANANTAPUR  Arecanut  2010-11  Whole Year   409.0
# 159     Andhra Pradesh      ANANTAPUR  Arecanut  2011-12  Whole Year   541.0
# 160     Andhra Pradesh      ANANTAPUR  Arecanut  2012-13      Kharif   558.0
# 161     Andhra Pradesh  EAST GODAVARI  Arecanut  2011-12  Whole Year    20.0
# 162     Andhra Pradesh  EAST GODAVARI  Arecanut  2012-13      Kharif    22.0
# ...                ...            ...       ...      ...         ...     ...
# 308125  Andhra Pradesh  WEST GODAVARI      Urad  2019-20        Rabi  3368.0
# 308126  Andhra Pradesh      ANANTAPUR     Wheat  2019-20        Rabi    10.0
# 308127  Andhra Pradesh         GUNTUR     Wheat  2019-20        Rabi     1.0
# 308128  Andhra Pradesh         KADAPA     Wheat  2019-20        Rabi     1.0
# 308129  Andhra Pradesh        KURNOOL     Wheat  2019-20        Rabi    25.0
#
# ...

# %%
sns.pairplot(AP,hue='Season')

# %% [markdown]
# ### Kharif season is the most crop production in  Andhra Pradesh.

# %%
States=agri.groupby('State')
Aru=States.get_group('Arunachal Pradesh')
Aru
# Out:
#                     State       District          Crop     Year      Season  \
# 2422    Arunachal Pradesh          ANJAW  Dry chillies  2010-11  Whole Year
# 2423    Arunachal Pradesh          ANJAW  Dry chillies  2011-12  Whole Year
# 2424    Arunachal Pradesh          ANJAW  Dry chillies  2012-13  Whole Year
# 2425    Arunachal Pradesh      CHANGLANG  Dry chillies  2010-11  Whole Year
# 2426    Arunachal Pradesh      CHANGLANG  Dry chillies  2011-12  Whole Year
# ...                   ...            ...           ...      ...         ...
# 308611  Arunachal Pradesh  PAKKE KESSANG         Wheat  2019-20        Rabi
# 308612  Arunachal Pradesh     PAPUM PARE         Wheat  2019-20        Rabi
# 308613  Arunachal Pradesh         TAWANG         Wheat  2019-20        Rabi
# 308614  Arunachal Pradesh          TIRAP         Wheat  2019-20        Rabi
# 308615  Arunachal Pradesh    WEST KAMENG         Wheat  2019-20        Rabi
#
# ...

# %%
sns.pairplot(Aru,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Arunachal Pradesh.

# %%
States=agri.groupby('State')
Assam=States.get_group('Assam')
Assam
# Out:
#         State   District      Crop     Year Season    Area Area_Units  \
# 2837    Assam      BAKSA  Arecanut  2010-11   Rabi  2500.0    Hectare
# 2838    Assam      BAKSA  Arecanut  2011-12   Rabi  2600.0    Hectare
# 2839    Assam      BAKSA  Arecanut  2012-13   Rabi  2500.0    Hectare
# 2840    Assam    BARPETA  Arecanut  2010-11   Rabi  3373.0    Hectare
# 2841    Assam    BARPETA  Arecanut  2011-12   Rabi  3351.0    Hectare
# ...       ...        ...       ...      ...    ...     ...        ...
# 309491  Assam    NALBARI     Wheat  2019-20   Rabi   137.0    Hectare
# 309492  Assam  SIVASAGAR     Wheat  2019-20   Rabi     3.0    Hectare
# 309493  Assam   SONITPUR     Wheat  2019-20   Rabi   307.0    Hectare
# 309494  Assam   TINSUKIA     Wheat  2019-20   Rabi    41.0    Hectare
# 309495  Assam   UDALGURI     Wheat  2019-20   Rabi   379.0    Hectare
#
#         Production Production_Units   Yield
# 2837        2411.0           Tonnes  0.9644
# ...

# %%
sns.pairplot(Assam,hue='Season',palette='tab10')

# %% [markdown]
# ### Winter season is the most crop production in  Assam.

# %%
States=agri.groupby('State')
Bihar=States.get_group('Bihar')
Bihar
# Out:
#         State  District       Crop     Year  Season     Area Area_Units  \
# 5433    Bihar    ARARIA  Arhar/Tur  2010-11  Kharif    122.0    Hectare
# 5434    Bihar    ARARIA  Arhar/Tur  2011-12  Kharif    118.0    Hectare
# 5435    Bihar    ARARIA  Arhar/Tur  2012-13  Kharif    118.0    Hectare
# 5436    Bihar     ARWAL  Arhar/Tur  2010-11  Kharif    451.0    Hectare
# 5437    Bihar     ARWAL  Arhar/Tur  2011-12  Kharif    442.0    Hectare
# ...       ...       ...        ...      ...     ...      ...        ...
# 262959  Bihar    SUPAUL      Wheat  2017-18    Rabi  52623.0    Hectare
# 262960  Bihar    SUPAUL      Wheat  2018-19    Rabi  53271.0    Hectare
# 262961  Bihar  VAISHALI      Wheat  2016-17    Rabi  43138.0    Hectare
# 262962  Bihar  VAISHALI      Wheat  2017-18    Rabi  40747.0    Hectare
# 262963  Bihar  VAISHALI      Wheat  2018-19    Rabi  40704.0    Hectare
#
#         Production Production_Units   Yield
# 5433          70.0           Tonnes  0.5738
# ...

# %%
sns.pairplot(Bihar,hue='Season',palette='tab10')

# %% [markdown]
# ### Whole year season is the most crop production in Bihar.

# %%
States=agri.groupby('State')
Chandigarh=States.get_group('Chandigarh')
Chandigarh
# Out:
#              State    District   Crop     Year      Season   Area Area_Units  \
# 8071    Chandigarh  CHANDIGARH  Maize  2010-11      Kharif   25.0    Hectare
# 8072    Chandigarh  CHANDIGARH  Maize  2011-12      Kharif   25.0    Hectare
# 8073    Chandigarh  CHANDIGARH  Maize  2012-13      Kharif   25.0    Hectare
# 8074    Chandigarh  CHANDIGARH  Onion  2010-11  Whole Year    3.0    Hectare
# 8075    Chandigarh  CHANDIGARH  Onion  2011-12  Whole Year    2.0    Hectare
# ...            ...         ...    ...      ...         ...    ...        ...
# 262968  Chandigarh  CHANDIGARH  Wheat  2017-18        Rabi  546.0    Hectare
# 262969  Chandigarh  CHANDIGARH  Wheat  2018-19        Rabi  546.0    Hectare
# 309496  Chandigarh  CHANDIGARH  Maize  2019-20      Kharif    8.0    Hectare
# 309497  Chandigarh  CHANDIGARH   Rice  2019-20      Kharif   80.0    Hectare
# 309498  Chandigarh  CHANDIGARH  Wheat  2019-20        Rabi  546.0    Hectare
#
#         Production Production_Units    Yield
# ...

# %%
sns.pairplot(Chandigarh,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in  Chandigarh.

# %%
States=agri.groupby('State')
Chhattisgarh=States.get_group('Chhattisgarh')
Chhattisgarh
# Out:
#                State      District       Crop     Year  Season    Area  \
# 8086    Chhattisgarh         BALOD  Arhar/Tur  2011-12  Kharif   607.0
# 8087    Chhattisgarh         BALOD  Arhar/Tur  2012-13  Kharif   571.0
# 8088    Chhattisgarh  BALODA BAZAR  Arhar/Tur  2011-12  Kharif  1492.0
# 8089    Chhattisgarh  BALODA BAZAR  Arhar/Tur  2012-13  Kharif  1430.0
# 8090    Chhattisgarh     BALRAMPUR  Arhar/Tur  2011-12  Kharif  8362.0
# ...              ...           ...        ...      ...     ...     ...
# 265653  Chhattisgarh      SURAJPUR      Wheat  2017-18    Rabi  5324.0
# 265654  Chhattisgarh      SURAJPUR      Wheat  2018-19    Rabi  5594.0
# 265655  Chhattisgarh       SURGUJA      Wheat  2016-17    Rabi  5199.0
# 265656  Chhattisgarh       SURGUJA      Wheat  2017-18    Rabi  5412.0
# 265657  Chhattisgarh       SURGUJA      Wheat  2018-19    Rabi  5280.0
#
#        Area_Units  Production Production_Units   Yield
# 8086      Hectare       290.0           Tonnes  0.4778
# ...

# %%
sns.pairplot(Chandigarh,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in  Chhattisgarh.

# %%
States=agri.groupby('State')
DNH=States.get_group('Dadra and Nagar Haveli')
DNH
# Out:
#                          State                District       Crop     Year  \
# 10610   Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Arhar/Tur  2010-11
# 10611   Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Arhar/Tur  2010-11
# 10612   Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Arhar/Tur  2011-12
# 10613   Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Arhar/Tur  2011-12
# 10614   Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Arhar/Tur  2012-13
# ...                        ...                     ...        ...      ...
# 309511  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI       Rice  2019-20
# 309512  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI    Sesamum  2019-20
# 309513  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI  Sugarcane  2019-20
# 309514  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI       Urad  2019-20
# 309515  Dadra and Nagar Haveli  DADRA AND NAGAR HAVELI      Wheat  2019-20
#
# ...

# %%
sns.pairplot(DNH,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Dadra and Nagar Haveli.

# %%
States=agri.groupby('State')
DD=States.get_group('Daman and Diu')
DD
# Out:
#                 State       District   Crop     Year  Season    Area  \
# 10665   Daman and Diu  Daman and Diu  Bajra  2010-11  Kharif   280.0
# 10666   Daman and Diu  Daman and Diu  Bajra  2011-12  Kharif   280.0
# 10667   Daman and Diu  Daman and Diu  Bajra  2012-13  Kharif   280.0
# 10668   Daman and Diu  Daman and Diu   Rice  2010-11  Kharif  2000.0
# 10669   Daman and Diu  Daman and Diu   Rice  2011-12  Kharif  2000.0
# 10670   Daman and Diu  Daman and Diu   Rice  2012-13  Kharif  2000.0
# 56627   Daman and Diu            DIU  Bajra  2013-14  Kharif   300.0
# 56628   Daman and Diu            DIU  Bajra  2014-15  Kharif   300.0
# 56629   Daman and Diu            DIU  Bajra  2015-16  Kharif   668.3
# 56630   Daman and Diu          DAMAN   Rice  2013-14  Kharif  2000.0
# 56631   Daman and Diu          DAMAN   Rice  2014-15  Kharif  1891.5
# 56632   Daman and Diu          DAMAN   Rice  2015-16  Kharif  1783.0
# 105797  Daman and Diu            DIU  Bajra  2016-17  Kharif   508.0
# ...

# %%
sns.pairplot(DD,hue='Season',palette='tab10')

# %%
### Kharif season is the most crop production in  Daman and Diu.

# %%
States=agri.groupby('State')
Delhi=States.get_group('Delhi')
Delhi
# Out:
#         State     District               Crop     Year  Season     Area  \
# 10671   Delhi  DELHI_TOTAL              Bajra  2010-11  Kharif   1531.0
# 10672   Delhi  DELHI_TOTAL              Bajra  2011-12  Kharif   1439.0
# 10673   Delhi  DELHI_TOTAL              Bajra  2012-13  Kharif   1519.0
# 10674   Delhi  DELHI_TOTAL             Barley  2010-11  Kharif     70.0
# 10675   Delhi  DELHI_TOTAL             Barley  2011-12  Kharif     66.0
# ...       ...          ...                ...      ...     ...      ...
# 309521  Delhi  DELHI_TOTAL              Jowar  2019-20  Kharif   3150.0
# 309522  Delhi  DELHI_TOTAL              Maize  2019-20  Kharif     20.0
# 309523  Delhi  DELHI_TOTAL  Rapeseed &Mustard  2019-20    Rabi   3250.0
# 309524  Delhi  DELHI_TOTAL               Rice  2019-20  Kharif   5848.0
# 309525  Delhi  DELHI_TOTAL              Wheat  2019-20    Rabi  19228.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(Delhi,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in Delhi.

# %%
States=agri.groupby('State')
Goa=States.get_group('Goa')
Goa
# Out:
#        State   District          Crop     Year      Season    Area Area_Units  \
# 10698    Goa  NORTH GOA     Groundnut  2010-11      Kharif   461.0    Hectare
# 10699    Goa  NORTH GOA     Groundnut  2010-11        Rabi  2418.0    Hectare
# 10700    Goa  NORTH GOA     Groundnut  2011-12      Kharif   357.0    Hectare
# 10701    Goa  NORTH GOA     Groundnut  2011-12        Rabi  2835.0    Hectare
# 10702    Goa  NORTH GOA     Groundnut  2012-13      Kharif   534.0    Hectare
# ...      ...        ...           ...      ...         ...     ...        ...
# 309546   Goa  SOUTH GOA          Rice  2019-20        Rabi  7291.0    Hectare
# 309547   Goa  NORTH GOA     Sugarcane  2019-20  Whole Year    81.0    Hectare
# 309548   Goa  SOUTH GOA     Sugarcane  2019-20  Whole Year   730.0    Hectare
# 309549   Goa  NORTH GOA  Sweet potato  2019-20  Whole Year    46.0    Hectare
# 309550   Goa  SOUTH GOA  Sweet potato  2019-20  Whole Year    20.0    Hectare
#
# ...

# %%
sns.pairplot(Goa,hue='Season',palette='tab10')

# %%
### Whole year season is the most crop production in  Goa.

# %%
States=agri.groupby('State')
Gujarat=States.get_group('Gujarat')
Gujarat
# Out:
#           State       District       Crop     Year  Season     Area  \
# 10742   Gujarat      AHMADABAD  Arhar/Tur  2010-11  Kharif   1100.0
# 10743   Gujarat      AHMADABAD  Arhar/Tur  2011-12  Kharif   1100.0
# 10744   Gujarat      AHMADABAD  Arhar/Tur  2012-13  Kharif   1000.0
# 10745   Gujarat         AMRELI  Arhar/Tur  2010-11  Kharif    700.0
# 10746   Gujarat         AMRELI  Arhar/Tur  2011-12  Kharif    900.0
# ...         ...            ...        ...      ...     ...      ...
# 310352  Gujarat   SABAR KANTHA      Wheat  2019-20    Rabi  95876.0
# 310353  Gujarat          SURAT      Wheat  2019-20    Rabi   3659.0
# 310354  Gujarat  SURENDRANAGAR      Wheat  2019-20    Rabi  65880.0
# 310355  Gujarat           TAPI      Wheat  2019-20    Rabi   5415.0
# 310356  Gujarat       VADODARA      Wheat  2019-20    Rabi  30248.0
#
#        Area_Units  Production Production_Units   Yield
# 10742     Hectare      1100.0           Tonnes  1.0000
# ...

# %%
sns.pairplot(Gujarat,hue='Season',palette='tab10')

# %% [markdown]
# ### Whole year season is the most crop production in  Gujarat.

# %%
States=agri.groupby('State')
Haryana=States.get_group('Haryana')
Haryana
# Out:
#           State     District       Crop     Year  Season      Area Area_Units  \
# 12696   Haryana       AMBALA  Arhar/Tur  2010-11  Kharif       3.0    Hectare
# 12697   Haryana      BHIWANI  Arhar/Tur  2010-11  Kharif    2684.0    Hectare
# 12698   Haryana      BHIWANI  Arhar/Tur  2011-12  Kharif    2583.0    Hectare
# 12699   Haryana      BHIWANI  Arhar/Tur  2012-13  Kharif     820.0    Hectare
# 12700   Haryana    FARIDABAD  Arhar/Tur  2011-12  Kharif     233.0    Hectare
# ...         ...          ...        ...      ...     ...       ...        ...
# 269011  Haryana        SIRSA      Wheat  2017-18    Rabi  295300.0    Hectare
# 269012  Haryana      SONIPAT      Wheat  2016-17    Rabi  144500.0    Hectare
# 269013  Haryana      SONIPAT      Wheat  2017-18    Rabi  144400.0    Hectare
# 269014  Haryana  YAMUNANAGAR      Wheat  2016-17    Rabi   89000.0    Hectare
# 269015  Haryana  YAMUNANAGAR      Wheat  2017-18    Rabi   89000.0    Hectare
#
# ...

# %%
sns.pairplot(Haryana,hue='Season',palette='tab10')

# %%
### Rabi season is the most crop production in  Haryana.

# %%
States=agri.groupby('State')
HP=States.get_group('Himachal Pradesh')
HP
# Out:
#                    State District       Crop     Year  Season     Area  \
# 13852   Himachal Pradesh   KANGRA  Arhar/Tur  2010-11  Kharif      1.0
# 13853   Himachal Pradesh   KANGRA  Arhar/Tur  2011-12  Kharif      1.0
# 13854   Himachal Pradesh   KANGRA  Arhar/Tur  2012-13  Kharif      5.0
# 13855   Himachal Pradesh   SHIMLA  Arhar/Tur  2010-11  Kharif      7.0
# 13856   Himachal Pradesh   SHIMLA  Arhar/Tur  2011-12  Kharif     10.0
# ...                  ...      ...        ...      ...     ...      ...
# 310625  Himachal Pradesh    MANDI      Wheat  2019-20    Rabi  58540.0
# 310626  Himachal Pradesh   SHIMLA      Wheat  2019-20    Rabi   7635.0
# 310627  Himachal Pradesh  SIRMAUR      Wheat  2019-20    Rabi  25675.0
# 310628  Himachal Pradesh    SOLAN      Wheat  2019-20    Rabi  28075.0
# 310629  Himachal Pradesh      UNA      Wheat  2019-20    Rabi  28505.0
#
#        Area_Units  Production Production_Units   Yield
# 13852     Hectare         NaN           Tonnes     NaN
# ...

# %%
sns.pairplot(HP,hue='Season',palette='tab10')

# %%
### Rabi season is the most crop production in Himachal Pradesh.

# %%
States=agri.groupby('State')
JK=States.get_group('Jammu and Kashmir')
JK
# Out:
#                     State  District       Crop     Year  Season     Area  \
# 14606   Jammu and Kashmir     SAMBA  Arhar/Tur  2010-11    Rabi      2.0
# 14607   Jammu and Kashmir     JAMMU      Bajra  2010-11  Kharif   9625.0
# 14608   Jammu and Kashmir     JAMMU      Bajra  2011-12  Kharif  10589.0
# 14609   Jammu and Kashmir     JAMMU      Bajra  2012-13  Kharif  10828.0
# 14610   Jammu and Kashmir    KATHUA      Bajra  2010-11  Kharif    977.0
# ...                   ...       ...        ...      ...     ...      ...
# 270601  Jammu and Kashmir     SAMBA      Wheat  2017-18    Rabi  29075.0
# 270602  Jammu and Kashmir     SAMBA      Wheat  2018-19    Rabi  29168.0
# 270603  Jammu and Kashmir  UDHAMPUR      Wheat  2016-17    Rabi  36906.0
# 270604  Jammu and Kashmir  UDHAMPUR      Wheat  2017-18    Rabi  39643.0
# 270605  Jammu and Kashmir  UDHAMPUR      Wheat  2018-19    Rabi  35569.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(JK,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in Jammu and Kashmir.

# %%
States=agri.groupby('State')
Jharkhand=States.get_group('Jharkhand')
Jharkhand
# Out:
#             State             District       Crop     Year Season     Area  \
# 15522   Jharkhand               BOKARO  Arhar/Tur  2010-11   Rabi    262.0
# 15523   Jharkhand               BOKARO  Arhar/Tur  2011-12   Rabi     75.0
# 15524   Jharkhand               BOKARO  Arhar/Tur  2012-13   Rabi     69.0
# 15525   Jharkhand               CHATRA  Arhar/Tur  2010-11   Rabi   1009.0
# 15526   Jharkhand               CHATRA  Arhar/Tur  2011-12   Rabi    934.0
# ...           ...                  ...        ...      ...    ...      ...
# 311108  Jharkhand               RANCHI      Wheat  2019-20   Rabi  12435.0
# 311109  Jharkhand            SAHEBGANJ      Wheat  2019-20   Rabi  12110.0
# 311110  Jharkhand  SARAIKELA KHARSAWAN      Wheat  2019-20   Rabi   3675.0
# 311111  Jharkhand              SIMDEGA      Wheat  2019-20   Rabi  10477.0
# 311112  Jharkhand       WEST SINGHBHUM      Wheat  2019-20   Rabi   1678.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(Jharkhand,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in Jharkhand.

# %%
States=agri.groupby('State')
Karnataka=States.get_group('Karnataka')
Karnataka
# Out:
#             State         District      Crop     Year      Season    Area  \
# 16222   Karnataka  BANGALORE RURAL  Arecanut  2010-11  Whole Year  1213.0
# 16223   Karnataka  BANGALORE RURAL  Arecanut  2011-12  Whole Year  1615.0
# 16224   Karnataka  BANGALORE RURAL  Arecanut  2012-13  Whole Year  1380.0
# 16225   Karnataka          BELGAUM  Arecanut  2010-11  Whole Year     1.0
# 16226   Karnataka          BELGAUM  Arecanut  2011-12  Whole Year     4.0
# ...           ...              ...       ...      ...         ...     ...
# 312708  Karnataka           MYSORE     Wheat  2019-20        Rabi     7.0
# 312709  Karnataka          RAICHUR     Wheat  2019-20        Rabi   132.0
# 312710  Karnataka       RAMANAGARA     Wheat  2019-20        Rabi     4.0
# 312711  Karnataka           TUMKUR     Wheat  2019-20        Rabi     6.0
# 312712  Karnataka           YADGIR     Wheat  2019-20        Rabi   147.0
#
#        Area_Units  Production Production_Units    Yield
# ...

# %%
sns.pairplot(Karnataka,hue='Season',palette='tab10')

# %% [markdown]
# ### Whole year season is the most crop production in Karnataka.

# %%
States=agri.groupby('State')
Kerala=States.get_group('Kerala')
Kerala
# Out:
#          State            District      Crop     Year      Season     Area  \
# 20342   Kerala           ALAPPUZHA  Arecanut  2010-11  Whole Year  1608.73
# 20343   Kerala           ALAPPUZHA  Arecanut  2011-12  Whole Year  1615.43
# 20344   Kerala           ALAPPUZHA  Arecanut  2012-13  Whole Year  1387.00
# 20345   Kerala           ERNAKULAM  Arecanut  2010-11  Whole Year  4549.93
# 20346   Kerala           ERNAKULAM  Arecanut  2011-12  Whole Year  4943.83
# ...        ...                 ...       ...      ...         ...      ...
# 312934  Kerala      PATHANAMTHITTA  Turmeric  2019-20  Whole Year   110.00
# 312935  Kerala  THIRUVANANTHAPURAM  Turmeric  2019-20  Whole Year    61.00
# 312936  Kerala            THRISSUR  Turmeric  2019-20  Whole Year    66.00
# 312937  Kerala             WAYANAD  Turmeric  2019-20  Whole Year   108.00
# 312938  Kerala              IDUKKI     Wheat  2019-20  Whole Year     1.00
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(Kerala,hue='Season',palette='tab10')

# %%
### Whole year season is the most crop production in Kerala.

# %%
States=agri.groupby('State')
MP=States.get_group('Madhya Pradesh')
MP
# Out:
#                  State   District       Crop     Year  Season      Area  \
# 20966   Madhya Pradesh  ALIRAJPUR  Arhar/Tur  2010-11  Kharif    2722.0
# 20967   Madhya Pradesh  ALIRAJPUR  Arhar/Tur  2011-12  Kharif    2677.0
# 20968   Madhya Pradesh  ALIRAJPUR  Arhar/Tur  2012-13  Kharif    2481.0
# 20969   Madhya Pradesh    ANUPPUR  Arhar/Tur  2010-11  Kharif    7389.0
# 20970   Madhya Pradesh    ANUPPUR  Arhar/Tur  2011-12  Kharif    6249.0
# ...                ...        ...        ...      ...     ...       ...
# 314486  Madhya Pradesh  SINGRAULI      Wheat  2019-20    Rabi   94045.0
# 314487  Madhya Pradesh  TIKAMGARH      Wheat  2019-20    Rabi  213491.0
# 314488  Madhya Pradesh     UJJAIN      Wheat  2019-20    Rabi  408353.0
# 314489  Madhya Pradesh     UMARIA      Wheat  2019-20    Rabi   75311.0
# 314490  Madhya Pradesh    VIDISHA      Wheat  2019-20    Rabi  383599.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(MP,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in Madhya Pradesh.

# %%
States=agri.groupby('State')
Manipur=States.get_group('Manipur')
Manipur
# Out:
#           State    District       Crop     Year  Season   Area Area_Units  \
# 27914   Manipur   BISHNUPUR  Arhar/Tur  2010-11  Kharif   90.0    Hectare
# 27915   Manipur   BISHNUPUR  Arhar/Tur  2011-12  Kharif   85.0    Hectare
# 27916   Manipur   BISHNUPUR  Arhar/Tur  2012-13  Kharif   50.0    Hectare
# 27917   Manipur     CHANDEL  Arhar/Tur  2010-11  Kharif   41.0    Hectare
# 27918   Manipur     CHANDEL  Arhar/Tur  2011-12  Kharif   92.0    Hectare
# ...         ...         ...        ...      ...     ...    ...        ...
# 283571  Manipur  TAMENGLONG      Wheat  2018-19    Rabi   10.0    Hectare
# 283572  Manipur     THOUBAL      Wheat  2016-17    Rabi  400.0    Hectare
# 283573  Manipur     THOUBAL      Wheat  2017-18    Rabi  400.0    Hectare
# 283574  Manipur     THOUBAL      Wheat  2018-19    Rabi  400.0    Hectare
# 283575  Manipur      UKHRUL      Wheat  2018-19    Rabi   10.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Manipur,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in Manipur.

# %%
States=agri.groupby('State')
Meghalaya=States.get_group('Meghalaya')
Meghalaya
# Out:
#             State               District      Crop     Year      Season  \
# 28499   Meghalaya        EAST GARO HILLS  Arecanut  2010-11  Whole Year
# 28500   Meghalaya        EAST GARO HILLS  Arecanut  2011-12  Whole Year
# 28501   Meghalaya        EAST GARO HILLS  Arecanut  2012-13  Whole Year
# 28502   Meghalaya     EAST JAINTIA HILLS  Arecanut  2010-11  Whole Year
# 28503   Meghalaya     EAST JAINTIA HILLS  Arecanut  2011-12  Whole Year
# ...           ...                    ...       ...      ...         ...
# 314788  Meghalaya        EAST GARO HILLS     Wheat  2019-20        Rabi
# 314789  Meghalaya       NORTH GARO HILLS     Wheat  2019-20        Rabi
# 314790  Meghalaya  SOUTH WEST GARO HILLS     Wheat  2019-20        Rabi
# 314791  Meghalaya        WEST GARO HILLS     Wheat  2019-20        Rabi
# 314792  Meghalaya       WEST KHASI HILLS     Wheat  2019-20        Rabi
#
#           Area Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(Meghalaya,hue='Season',palette='tab10')

# %% [markdown]
# ### Whole year season is the most crop production in  Meghalaya.

# %%
States=agri.groupby('State')
Mizoram=States.get_group('Mizoram')
Mizoram
# Out:
#           State   District       Crop     Year      Season  Area Area_Units  \
# 28999   Mizoram     AIZAWL  Arhar/Tur  2010-11      Kharif  58.0    Hectare
# 29000   Mizoram     AIZAWL  Arhar/Tur  2011-12      Kharif  38.0    Hectare
# 29001   Mizoram     AIZAWL  Arhar/Tur  2012-13      Kharif   2.0    Hectare
# 29002   Mizoram   CHAMPHAI  Arhar/Tur  2010-11      Kharif  20.0    Hectare
# 29003   Mizoram   CHAMPHAI  Arhar/Tur  2011-12      Kharif  38.0    Hectare
# ...         ...        ...        ...      ...         ...   ...        ...
# 284835  Mizoram  LAWNGTLAI    Tobacco  2017-18      Kharif  50.5    Hectare
# 284836  Mizoram  LAWNGTLAI    Tobacco  2018-19      Kharif  50.0    Hectare
# 284837  Mizoram    LUNGLEI    Tobacco  2016-17  Whole Year  30.0    Hectare
# 284838  Mizoram    LUNGLEI    Tobacco  2017-18      Kharif  35.0    Hectare
# 284839  Mizoram    LUNGLEI    Tobacco  2018-19      Kharif  32.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Mizoram,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Mizoram.

# %%
States=agri.groupby('State')
Nagaland=States.get_group('Nagaland')
Nagaland
# Out:
#            State   District       Crop     Year  Season   Area Area_Units  \
# 29327   Nagaland    DIMAPUR  Arhar/Tur  2010-11  Kharif  400.0    Hectare
# 29328   Nagaland    DIMAPUR  Arhar/Tur  2011-12  Kharif  410.0    Hectare
# 29329   Nagaland    DIMAPUR  Arhar/Tur  2012-13  Kharif  450.0    Hectare
# 29330   Nagaland    KIPHIRE  Arhar/Tur  2010-11  Kharif   80.0    Hectare
# 29331   Nagaland    KIPHIRE  Arhar/Tur  2011-12  Kharif   80.0    Hectare
# ...          ...        ...        ...      ...     ...    ...        ...
# 315154  Nagaland      PEREN      Wheat  2019-20    Rabi  381.0    Hectare
# 315155  Nagaland       PHEK      Wheat  2019-20    Rabi  351.0    Hectare
# 315156  Nagaland   TUENSANG      Wheat  2019-20    Rabi  341.0    Hectare
# 315157  Nagaland      WOKHA      Wheat  2019-20    Rabi  371.0    Hectare
# 315158  Nagaland  ZUNHEBOTO      Wheat  2019-20    Rabi  321.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Nagaland,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Nagaland.

# %%
States=agri.groupby('State')
Odisha=States.get_group('Odisha')
Odisha
# Out:
#          State     District       Crop     Year  Season    Area Area_Units  \
# 30233   Odisha       ANUGUL  Groundnut  2010-11  Autumn  2285.0    Hectare
# 30234   Odisha       ANUGUL  Groundnut  2010-11  Summer   489.0    Hectare
# 30235   Odisha       ANUGUL  Groundnut  2010-11  Winter   252.0    Hectare
# 30236   Odisha       ANUGUL  Groundnut  2011-12  Autumn  1923.0    Hectare
# 30237   Odisha       ANUGUL  Groundnut  2011-12  Summer   212.0    Hectare
# ...        ...          ...        ...      ...     ...     ...        ...
# 287541  Odisha  NABARANGPUR      Wheat  2018-19  Summer     3.0    Hectare
# 287542  Odisha    SAMBALPUR      Wheat  2018-19  Summer     3.0    Hectare
# 287543  Odisha   SUNDARGARH      Wheat  2016-17  Summer    45.0    Hectare
# 287544  Odisha   SUNDARGARH      Wheat  2017-18  Summer    22.0    Hectare
# 287545  Odisha   SUNDARGARH      Wheat  2018-19  Summer    62.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Odisha,hue='Season',palette='tab10')

# %% [markdown]
# ### Summer season is the most crop production in  Odisha.

# %%
States=agri.groupby('State')
Puducherry=States.get_group('Puducherry')
Puducherry
# Out:
#              State     District      Crop     Year  Season   Area Area_Units  \
# 32041   Puducherry         MAHE  Arecanut  2010-11  Kharif   60.0    Hectare
# 32042   Puducherry         MAHE  Arecanut  2011-12  Kharif   60.0    Hectare
# 32043   Puducherry  PONDICHERRY     Bajra  2010-11  Kharif   29.0    Hectare
# 32044   Puducherry  PONDICHERRY     Bajra  2010-11  Summer    5.0    Hectare
# 32045   Puducherry  PONDICHERRY     Bajra  2011-12  Kharif   11.0    Hectare
# ...            ...          ...       ...      ...     ...    ...        ...
# 315214  Puducherry     KARAIKAL      Urad  2019-20  Summer  255.0    Hectare
# 315215  Puducherry  PONDICHERRY      Urad  2019-20  Kharif    2.0    Hectare
# 315216  Puducherry  PONDICHERRY      Urad  2019-20    Rabi  146.0    Hectare
# 315217  Puducherry  PONDICHERRY      Urad  2019-20  Summer   58.0    Hectare
# 315218  Puducherry        YANAM      Urad  2019-20  Summer    8.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Puducherry,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Puducherry.

# %%
States=agri.groupby('State')
Punjab=States.get_group('Punjab')
Punjab
# Out:
#          State    District       Crop     Year  Season      Area Area_Units  \
# 32217   Punjab    AMRITSAR  Arhar/Tur  2010-11  Kharif     100.0    Hectare
# 32218   Punjab    AMRITSAR  Arhar/Tur  2011-12  Kharif     100.0    Hectare
# 32219   Punjab    AMRITSAR  Arhar/Tur  2012-13  Kharif     100.0    Hectare
# 32220   Punjab     BARNALA  Arhar/Tur  2010-11  Kharif     100.0    Hectare
# 32221   Punjab     BARNALA  Arhar/Tur  2011-12  Kharif     100.0    Hectare
# ...        ...         ...        ...      ...     ...       ...        ...
# 315417  Punjab     PATIALA      Wheat  2019-20    Rabi  234000.0    Hectare
# 315418  Punjab    RUPNAGAR      Wheat  2019-20    Rabi   69000.0    Hectare
# 315419  Punjab           S      Wheat  2019-20    Rabi   50000.0    Hectare
# 315420  Punjab     SANGRUR      Wheat  2019-20    Rabi  291000.0    Hectare
# 315421  Punjab  TARN TARAN      Wheat  2019-20    Rabi  188000.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Punjab,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in  Punjab.

# %%
States=agri.groupby('State')
Rajasthan=States.get_group('Rajasthan')
Rajasthan
# Out:
#             State        District       Crop     Year  Season     Area  \
# 32719   Rajasthan           AJMER  Arhar/Tur  2010-11  Kharif      7.0
# 32720   Rajasthan           AJMER  Arhar/Tur  2011-12  Kharif     47.0
# 32721   Rajasthan           ALWAR  Arhar/Tur  2010-11  Kharif   5064.0
# 32722   Rajasthan           ALWAR  Arhar/Tur  2011-12  Kharif   4034.0
# 32723   Rajasthan           ALWAR  Arhar/Tur  2012-13  Kharif   2925.0
# ...           ...             ...        ...      ...     ...      ...
# 316311  Rajasthan  SAWAI MADHOPUR      Wheat  2019-20    Rabi  73934.0
# 316312  Rajasthan           SIKAR      Wheat  2019-20    Rabi  84746.0
# 316313  Rajasthan          SIROHI      Wheat  2019-20    Rabi  33732.0
# 316314  Rajasthan            TONK      Wheat  2019-20    Rabi  59993.0
# 316315  Rajasthan         UDAIPUR      Wheat  2019-20    Rabi  83198.0
#
#        Area_Units  Production Production_Units   Yield
# 32719     Hectare         7.0           Tonnes  1.0000
# ...

# %%
sns.pairplot(Rajasthan,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in  Rajasthan.

# %%
States=agri.groupby('State')
Sikkim=States.get_group('Sikkim')
Sikkim
# Out:
#          State        District    Crop     Year  Season    Area Area_Units  \
# 35443   Sikkim   EAST DISTRICT  Barley  2010-11    Rabi   320.0    Hectare
# 35444   Sikkim   EAST DISTRICT  Barley  2011-12    Rabi   300.0    Hectare
# 35445   Sikkim   EAST DISTRICT  Barley  2012-13    Rabi   240.0    Hectare
# 35446   Sikkim  NORTH DISTRICT  Barley  2010-11    Rabi   140.0    Hectare
# 35447   Sikkim  NORTH DISTRICT  Barley  2011-12    Rabi   140.0    Hectare
# ...        ...             ...     ...      ...     ...     ...        ...
# 316347  Sikkim   EAST DISTRICT    Urad  2019-20  Kharif   455.0    Hectare
# 316348  Sikkim  SOUTH DISTRICT    Urad  2019-20  Kharif  1700.0    Hectare
# 316349  Sikkim   WEST DISTRICT    Urad  2019-20  Kharif   634.0    Hectare
# 316350  Sikkim   EAST DISTRICT   Wheat  2019-20    Rabi   113.0    Hectare
# 316351  Sikkim  NORTH DISTRICT   Wheat  2019-20    Rabi    52.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Sikkim,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Sikkim.

# %%
States=agri.groupby('State')
TN=States.get_group('Tamil Nadu')
TN
# Out:
#              State      District      Crop     Year      Season     Area  \
# 35554   Tamil Nadu    COIMBATORE  Arecanut  2011-12  Whole Year   1732.0
# 35555   Tamil Nadu     CUDDALORE  Arecanut  2011-12  Whole Year      1.0
# 35556   Tamil Nadu    DHARMAPURI  Arecanut  2011-12  Whole Year    402.0
# 35557   Tamil Nadu      DINDIGUL  Arecanut  2011-12  Whole Year     48.0
# 35558   Tamil Nadu         ERODE  Arecanut  2011-12  Whole Year    233.0
# ...            ...           ...       ...      ...         ...      ...
# 317650  Tamil Nadu       VELLORE      Urad  2019-20        Rabi   2241.0
# 317651  Tamil Nadu    VILLUPURAM      Urad  2019-20      Kharif   4567.0
# 317652  Tamil Nadu    VILLUPURAM      Urad  2019-20        Rabi  79945.0
# 317653  Tamil Nadu  VIRUDHUNAGAR      Urad  2019-20      Kharif    343.0
# 317654  Tamil Nadu  VIRUDHUNAGAR      Urad  2019-20        Rabi   3900.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(TN,hue='Season',palette='tab10')

# %% [markdown]
# ### Whole year season is the most crop production in  Tamil Nadu.

# %%
States=agri.groupby('State')
Telangana=States.get_group('Telangana')
Telangana
# Out:
#             State    District       Crop     Year  Season     Area Area_Units  \
# 83777   Telangana    ADILABAD  Arhar/Tur  2013-14  Kharif  39190.0    Hectare
# 83778   Telangana    ADILABAD  Arhar/Tur  2013-14    Rabi   1067.0    Hectare
# 83779   Telangana    ADILABAD  Arhar/Tur  2014-15  Kharif  34731.0    Hectare
# 83780   Telangana    ADILABAD  Arhar/Tur  2014-15    Rabi    543.0    Hectare
# 83781   Telangana    ADILABAD  Arhar/Tur  2015-16  Kharif  37507.0    Hectare
# ...           ...         ...        ...      ...     ...      ...        ...
# 318675  Telangana     RAJANNA      Wheat  2019-20    Rabi     47.0    Hectare
# 318676  Telangana  RANGAREDDI      Wheat  2019-20    Rabi     14.0    Hectare
# 318677  Telangana  SANGAREDDY      Wheat  2019-20    Rabi    110.0    Hectare
# 318678  Telangana    SIDDIPET      Wheat  2019-20    Rabi      7.0    Hectare
# 318679  Telangana   VIKARABAD      Wheat  2019-20    Rabi     46.0    Hectare
#
# ...

# %%
sns.pairplot(Telangana,hue='Season',palette='tab10')

# %% [markdown]
# ### Rabi season is the most crop production in  Telangana.

# %%
States=agri.groupby('State')
Tripura=States.get_group('Tripura')
Tripura
# Out:
#           State      District       Crop     Year  Season   Area Area_Units  \
# 37284   Tripura        DHALAI  Arhar/Tur  2010-11  Kharif  176.0    Hectare
# 37285   Tripura        DHALAI  Arhar/Tur  2011-12  Kharif  388.0    Hectare
# 37286   Tripura        DHALAI  Arhar/Tur  2012-13  Kharif  422.0    Hectare
# 37287   Tripura        GOMATI  Arhar/Tur  2012-13  Kharif  108.0    Hectare
# 37288   Tripura        KHOWAI  Arhar/Tur  2012-13  Kharif  163.0    Hectare
# ...         ...           ...        ...      ...     ...    ...        ...
# 318926  Tripura        GOMATI      Wheat  2019-20    Rabi   24.0    Hectare
# 318927  Tripura        KHOWAI      Wheat  2019-20    Rabi   20.0    Hectare
# 318928  Tripura    SEPAHIJALA      Wheat  2019-20    Rabi   25.0    Hectare
# 318929  Tripura       UNAKOTI      Wheat  2019-20    Rabi   24.0    Hectare
# 318930  Tripura  WEST TRIPURA      Wheat  2019-20    Rabi   25.0    Hectare
#
#         Production Production_Units   Yield
# ...

# %%
sns.pairplot(Tripura,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Tripura.

# %%
States=agri.groupby('State')
UP=States.get_group('Uttar Pradesh')
UP
# Out:
#                 State  District       Crop     Year  Season      Area  \
# 37618   Uttar Pradesh      AGRA  Arhar/Tur  2010-11  Kharif     974.0
# 37619   Uttar Pradesh      AGRA  Arhar/Tur  2011-12  Kharif     948.0
# 37620   Uttar Pradesh      AGRA  Arhar/Tur  2012-13  Kharif     884.0
# 37621   Uttar Pradesh   ALIGARH  Arhar/Tur  2010-11  Kharif   14506.0
# 37622   Uttar Pradesh   ALIGARH  Arhar/Tur  2011-12  Kharif   12401.0
# ...               ...       ...        ...      ...     ...       ...
# 304741  Uttar Pradesh     UNNAO      Wheat  2017-18    Rabi  244358.0
# 304742  Uttar Pradesh     UNNAO      Wheat  2018-19    Rabi  241879.0
# 304743  Uttar Pradesh  VARANASI      Wheat  2016-17    Rabi   70914.0
# 304744  Uttar Pradesh  VARANASI      Wheat  2017-18    Rabi   69363.0
# 304745  Uttar Pradesh  VARANASI      Wheat  2018-19    Rabi   68973.0
#
#        Area_Units  Production Production_Units   Yield
# 37618     Hectare       666.0           Tonnes  0.6838
# ...

# %%
sns.pairplot(UP,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in Uttar Pradesh.

# %%
States=agri.groupby('State')
Uttarakhand=States.get_group('Uttarakhand')
Uttarakhand
# Out:
#               State          District       Crop     Year  Season      Area  \
# 43771   Uttarakhand            ALMORA  Arhar/Tur  2010-11  Kharif       4.0
# 43772   Uttarakhand            ALMORA  Arhar/Tur  2011-12  Kharif      51.0
# 43773   Uttarakhand            ALMORA  Arhar/Tur  2012-13  Kharif      24.0
# 43774   Uttarakhand         BAGESHWAR  Arhar/Tur  2011-12  Kharif      19.0
# 43775   Uttarakhand         BAGESHWAR  Arhar/Tur  2012-13  Kharif       2.0
# ...             ...               ...        ...      ...     ...       ...
# 319240  Uttarakhand       PITHORAGARH      Wheat  2019-20    Rabi   16776.0
# 319241  Uttarakhand      RUDRA PRAYAG      Wheat  2019-20    Rabi    9671.0
# 319242  Uttarakhand     TEHRI GARHWAL      Wheat  2019-20    Rabi   16985.0
# 319243  Uttarakhand  UDAM SINGH NAGAR      Wheat  2019-20    Rabi  104706.0
# 319244  Uttarakhand       UTTAR KASHI      Wheat  2019-20    Rabi    9489.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(Uttarakhand,hue='Season',palette='tab10')

# %% [markdown]
# ### Kharif season is the most crop production in  Uttarakhand.

# %%
States=agri.groupby('State')
WB=States.get_group('West Bengal')
WB
# Out:
#               State            District       Crop     Year Season     Area  \
# 44701   West Bengal  24 PARAGANAS SOUTH  Arhar/Tur  2010-11   Rabi    455.0
# 44702   West Bengal  24 PARAGANAS SOUTH  Arhar/Tur  2011-12   Rabi    436.0
# 44703   West Bengal  24 PARAGANAS SOUTH  Arhar/Tur  2012-13   Rabi    514.0
# 44704   West Bengal             BIRBHUM  Arhar/Tur  2011-12   Rabi     11.0
# 44705   West Bengal             BIRBHUM  Arhar/Tur  2012-13   Rabi      2.0
# ...             ...                 ...        ...      ...    ...      ...
# 319817  West Bengal         MURSHIDABAD      Wheat  2019-20   Rabi  52709.0
# 319818  West Bengal               NADIA      Wheat  2019-20   Rabi   6188.0
# 319819  West Bengal   PASCHIM BARDHAMAN      Wheat  2019-20   Rabi    929.0
# 319820  West Bengal     PURBA BARDHAMAN      Wheat  2019-20   Rabi   1832.0
# 319821  West Bengal             PURULIA      Wheat  2019-20   Rabi    516.0
#
#        Area_Units  Production Production_Units   Yield
# ...

# %%
sns.pairplot(WB,hue='Season',palette='tab10')

# %% [markdown]
# ### Winter season is the most crop production in  West Bengal.

# %%
sns.pairplot(agri,hue='Season')

# %% [markdown]
# ### In the above pairplot shows the overall season  wise production. Kharif and whole year season is the most crops produced in the year between 2010-2020.
